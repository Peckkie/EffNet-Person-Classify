# %% [markdown]
# # 🔗train set

# %%
# Train
import pandas as pd
dataframe = pd.read_csv('/home/yupaporn/code/EffNet-Person-Classify/data_label_by_tan_10082023_splited_imgpath28_train.csv') #แก้ data เปลี่ยนตาม fold
# dataframe = dataframe[dataframe['img_no'] ==1]
dataframe = dataframe.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'])
print(dataframe.shape)
dataframe.head()
# Out:
# (180689, 12)
# /home/yupaporn/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                             path_img  img_no   branch  \
# 0  /media/hdd/tan/code/Show-Images/static/BearHou...       1  Fashion
# 1  /media/hdd/tan/code/Show-Images/static/BearHou...       2  Fashion
# 2  /media/hdd/tan/code/Show-Images/static/BearHou...       3  Fashion
# 3  /media/hdd/tan/code/Show-Images/static/BearHou...       4  Fashion
# 4  /media/hdd/tan/code/Show-Images/static/BearHou...       5  Fashion
#
#                                      Path_folder_web camera_angle gender  \
# 0  BearHouse-Person/Fashion_ch3_20230310145957_20...          ch3    Men
# 1  BearHouse-Person/Fashion_ch3_20230310145957_20...          ch3    Men
# 2  BearHouse-Person/Fashion_ch3_20230310145957_20...          ch3    Men
# 3  BearHouse-Person/Fashion_ch3_20230310145957_20...          ch3    Men
# 4  BearHouse-Person/Fashion_ch3_20230310145957_20...          ch3    Men
#
#   category work_by status   clip_from  split  \
# 0  Student     Nat    NaN  Bear-House  train
# 1  Student     Nat    NaN  Bear-House  train
# 2  Student     Nat    NaN  Bear-House  train
# 3  Student     Nat    NaN  Bear-House  train
# 4  Student     Nat    NaN  Bear-House  train
#
#                                          path_img_28
# 0  /media/HDD/BearHouse-Person/Fashion_ch3_202303...
# 1  /media/HDD/BearHouse-Person/Fashion_ch3_202303...
# 2  /media/HDD/BearHouse-Person/Fashion_ch3_202303...
# 3  /media/HDD/BearHouse-Person/Fashion_ch3_202303...
# 4  /media/HDD/BearHouse-Person/Fashion_ch3_202303...

# %%
# Train
import pandas as pd
dataframe1 = pd.read_csv('/home/yupaporn/code/EffNet-Person-Classify/data_label_by_tan_08102023_splited_imgpath28_train.csv') #แก้ data เปลี่ยนตาม fold
# dataframe = dataframe[dataframe['img_no'] ==1]
dataframe1 = dataframe1.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'])
print(dataframe1.shape)
dataframe1.head()
# Out:
# (9439, 12)
#                                             path_img  img_no branch  \
# 0  /media/hdd/tan/code/Show-Images/static/BearHou...       1  kampu
# 1  /media/hdd/tan/code/Show-Images/static/BearHou...       2  kampu
# 2  /media/hdd/tan/code/Show-Images/static/BearHou...       3  kampu
# 3  /media/hdd/tan/code/Show-Images/static/BearHou...       4  kampu
# 4  /media/hdd/tan/code/Show-Images/static/BearHou...       5  kampu
#
#                                      Path_folder_web camera_angle gender  \
# 0  BearHouse-Person/kampu_ch4_20230310150002_2023...          ch4  Women
# 1  BearHouse-Person/kampu_ch4_20230310150002_2023...          ch4  Women
# 2  BearHouse-Person/kampu_ch4_20230310150002_2023...          ch4  Women
# 3  BearHouse-Person/kampu_ch4_20230310150002_2023...          ch4  Women
# 4  BearHouse-Person/kampu_ch4_20230310150002_2023...          ch4  Women
#
#   category work_by  status   clip_from  split  \
# 0  Student     Nat     NaN  Bear-House  train
# 1  Student     Nat     NaN  Bear-House  train
# 2  Student     Nat     NaN  Bear-House  train
# 3  Student     Nat     NaN  Bear-House  train
# 4  Student     Nat     NaN  Bear-House  train
#
#                                          path_img_28
# 0  /media/HDD/BearHouse-Person/kampu_ch4_20230310...
# 1  /media/HDD/BearHouse-Person/kampu_ch4_20230310...
# 2  /media/HDD/BearHouse-Person/kampu_ch4_20230310...
# 3  /media/HDD/BearHouse-Person/kampu_ch4_20230310...
# 4  /media/HDD/BearHouse-Person/kampu_ch4_20230310...

# %%
dataframe = dataframe.append(dataframe1)
print(dataframe.shape)
# Out:
# (190128, 12)

# %%
# path_men = dataframe['path_img_28'].tolist()
# path_men

# %%
img_no_df = dataframe[dataframe['Path_folder_web'] =='']
paths= list(set(dataframe['Path_folder_web']))
for i in range(len(paths)):
    dff = dataframe[dataframe['Path_folder_web'] ==paths[i]]
    image_no = int(len(dff)/2)
    img_no = dff[dff['img_no'] == image_no]
    img_no_df = img_no_df.append(img_no)
    
print(img_no_df.shape)
img_no_df.head()

path_men = img_no_df['path_img_28'].tolist()
# Out:
# (2683, 12)

# %%
import shutil
import os
path_men_new = []
img_new = []
train_dir = '/media/HDD/BearHouse-Person-Data/data_R3_middleframe/train/'
for i in range(len(path_men)):
    filename = str(i) + '_' + path_men[i].split('/')[-1]
    img_new.append(filename)
    filename_path = train_dir + filename
    path_men_new.append(filename_path)
    # moving image
    dst = os.path.join(train_dir,filename)
    shutil.copyfile(path_men[i], dst)

# %%
img_no_df['path_img_28_train'] = path_men_new
img_no_df['img_28_train'] = img_new
img_no_df.to_csv('/home/yupaporn/code/EffNet-Person-Classify/data_label_by_tan_09102023_splited_imgpath28_train_middleframe.csv')

# %% [markdown]
# # 🔗valiodation set

# %%
# validation
import pandas as pd
valframe = pd.read_csv( '/home/yupaporn/code/EffNet-Person-Classify/data_label_by_tan_10082023_splited_imgpath28_val.csv') #เปลี่ยนตาม fold
print(valframe.shape)
valframe.head()
# Out:
# (45982, 14)
#    Unnamed: 0  Unnamed: 0.1  \
# 0         793            51
# 1         794            28
# 2         795            33
# 3         796            42
# 4         797            81
#
#                                             path_img  img_no    branch  \
# 0  /media/hdd/tan/code/Show-Images/static/BearHou...       1  Camera17
# 1  /media/hdd/tan/code/Show-Images/static/BearHou...       2  Camera17
# 2  /media/hdd/tan/code/Show-Images/static/BearHou...       3  Camera17
# 3  /media/hdd/tan/code/Show-Images/static/BearHou...       4  Camera17
# 4  /media/hdd/tan/code/Show-Images/static/BearHou...       5  Camera17
#
#                                      Path_folder_web camera_angle gender  \
# 0  BearHouse-Person/IP Camera17_kku2_kku2_2023061...         kku2    Men
# 1  BearHouse-Person/IP Camera17_kku2_kku2_2023061...         kku2    Men
# 2  BearHouse-Person/IP Camera17_kku2_kku2_2023061...         kku2    Men
# 3  BearHouse-Person/IP Camera17_kku2_kku2_2023061...         kku2    Men
# 4  BearHouse-Person/IP Camera17_kku2_kku2_2023061...         kku2    Men
#
#   category work_by status   clip_from split  \
# 0  Student    Yoke    NaN  Bear-House   val
# 1  Student    Yoke    NaN  Bear-House   val
# 2  Student    Yoke    NaN  Bear-House   val
# 3  Student    Yoke    NaN  Bear-House   val
# 4  Student    Yoke    NaN  Bear-House   val
#
#                                          path_img_28
# 0  /media/HDD/BearHouse-Person/IP Camera17_kku2_k...
# 1  /media/HDD/BearHouse-Person/IP Camera17_kku2_k...
# 2  /media/HDD/BearHouse-Person/IP Camera17_kku2_k...
# 3  /media/HDD/BearHouse-Person/IP Camera17_kku2_k...
# 4  /media/HDD/BearHouse-Person/IP Camera17_kku2_k...

# %%
# validation
import pandas as pd
valframe1 = pd.read_csv( '/home/yupaporn/code/EffNet-Person-Classify/data_label_by_tan_08102023_splited_imgpath28_val.csv') #เปลี่ยนตาม fold
print(valframe1.shape)
valframe1.head()
# Out:
# (987, 14)
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0            94
# 1           1            66
# 2           2            14
# 3           3            76
# 4           4            47
#
#                                             path_img  img_no  branch  \
# 0  /media/hdd/tan/code/Show-Images/static/BearHou...       1  siilom
# 1  /media/hdd/tan/code/Show-Images/static/BearHou...       2  siilom
# 2  /media/hdd/tan/code/Show-Images/static/BearHou...       3  siilom
# 3  /media/hdd/tan/code/Show-Images/static/BearHou...       4  siilom
# 4  /media/hdd/tan/code/Show-Images/static/BearHou...       5  siilom
#
#                                      Path_folder_web camera_angle gender  \
# 0  BearHouse-Person/siilom_ch1_20230310130011_202...          ch1  Women
# 1  BearHouse-Person/siilom_ch1_20230310130011_202...          ch1  Women
# 2  BearHouse-Person/siilom_ch1_20230310130011_202...          ch1  Women
# 3  BearHouse-Person/siilom_ch1_20230310130011_202...          ch1  Women
# 4  BearHouse-Person/siilom_ch1_20230310130011_202...          ch1  Women
#
#   category work_by  status   clip_from split  \
# 0  Student     Tan     NaN  Bear-House   val
# 1  Student     Tan     NaN  Bear-House   val
# 2  Student     Tan     NaN  Bear-House   val
# 3  Student     Tan     NaN  Bear-House   val
# 4  Student     Tan     NaN  Bear-House   val
#
#                                          path_img_28
# 0  /media/HDD/BearHouse-Person/siilom_ch1_2023031...
# 1  /media/HDD/BearHouse-Person/siilom_ch1_2023031...
# 2  /media/HDD/BearHouse-Person/siilom_ch1_2023031...
# 3  /media/HDD/BearHouse-Person/siilom_ch1_2023031...
# 4  /media/HDD/BearHouse-Person/siilom_ch1_2023031...

# %%
valframe = valframe.append(valframe1)
print(valframe.shape)
# Out:
# (46969, 14)

# %%
img_no_df = valframe[valframe['Path_folder_web'] =='']
paths= list(set(valframe['Path_folder_web']))
for i in range(len(paths)):
    dff = valframe[valframe['Path_folder_web'] ==paths[i]]
    image_no = int(len(dff)/2)
    img_no = dff[dff['img_no'] == image_no]
    img_no_df = img_no_df.append(img_no)
    
print(img_no_df.shape)
img_no_df.head()

path_men = img_no_df['path_img_28'].tolist()
# Out:
# (657, 14)

# %%
import shutil
import os
path_men_new = []
img_new = []
val_dir = '/media/HDD/BearHouse-Person-Data/data_R3_middleframe/validation/'

for i in range(len(path_men)):
    filename = str(i) + '_' + path_men[i].split('/')[-1]
    filename_path = val_dir + filename
    img_new.append(filename)
    path_men_new.append(filename_path)
    # moving image
    dst = os.path.join(val_dir,filename)
    shutil.copyfile(path_men[i], dst)
    
img_no_df['path_img_28_train'] = path_men_new
img_no_df['img_28_train'] = img_new
img_no_df.to_csv('/home/yupaporn/code/EffNet-Person-Classify/data_label_by_tan_09102023_splited_imgpath28_val_middleframe.csv')

# %% [markdown]
# # 🔗test set

# %%
#validation
import pandas as pd
testframe = pd.read_csv('/home/yupaporn/code/EffNet-Person-Classify/data_label_by_tan_08102023_splited_imgpath28.csv') 
testframe = testframe[testframe['split'] =='test']
# testframe = testframe[testframe['img_no'] ==1]
print(testframe.shape)
testframe.head()
# Out:
# (40569, 14)
#        Unnamed: 0  Unnamed: 0.1  \
# 10426       10426            31
# 10427       10427            29
# 10428       10428             0
# 10429       10429            13
# 10430       10430            22
#
#                                                 path_img  img_no branch  \
# 10426  /media/hdd/tan/code/Show-Images/static/BearHou...       1  kampu
# 10427  /media/hdd/tan/code/Show-Images/static/BearHou...       2  kampu
# 10428  /media/hdd/tan/code/Show-Images/static/BearHou...       3  kampu
# 10429  /media/hdd/tan/code/Show-Images/static/BearHou...       4  kampu
# 10430  /media/hdd/tan/code/Show-Images/static/BearHou...       5  kampu
#
#                                          Path_folder_web camera_angle gender  \
# 10426  BearHouse-Person/kampu_ch4_20230310150002_2023...          ch4    Men
# 10427  BearHouse-Person/kampu_ch4_20230310150002_2023...          ch4    Men
# 10428  BearHouse-Person/kampu_ch4_20230310150002_2023...          ch4    Men
# 10429  BearHouse-Person/kampu_ch4_20230310150002_2023...          ch4    Men
# 10430  BearHouse-Person/kampu_ch4_20230310150002_2023...          ch4    Men
#
#       category work_by  status   clip_from split  \
# 10426  Working     Nat     NaN  Bear-House  test
# 10427  Working     Nat     NaN  Bear-House  test
# 10428  Working     Nat     NaN  Bear-House  test
# 10429  Working     Nat     NaN  Bear-House  test
# 10430  Working     Nat     NaN  Bear-House  test
#
#                                              path_img_28
# 10426  /media/HDD/BearHouse-Person/kampu_ch4_20230310...
# 10427  /media/HDD/BearHouse-Person/kampu_ch4_20230310...
# 10428  /media/HDD/BearHouse-Person/kampu_ch4_20230310...
# 10429  /media/HDD/BearHouse-Person/kampu_ch4_20230310...
# 10430  /media/HDD/BearHouse-Person/kampu_ch4_20230310...

# %%
#validation
import pandas as pd
testframe1 = pd.read_csv('/home/yupaporn/code/EffNet-Person-Classify/data_label_by_tan_10082023_splited_imgpath28.csv') 
testframe1 = testframe1[testframe1['split'] =='test']
# testframe = testframe[testframe['img_no'] ==1]
print(testframe1.shape)
testframe1.head()
# Out:
# (56520, 14)
# /home/yupaporn/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         Unnamed: 0  Unnamed: 0.1  \
# 226671      226671            31
# 226672      226672            27
# 226673      226673            23
# 226674      226674             6
# 226675      226675            28
#
#                                                  path_img  img_no branch  \
# 226671  /media/hdd/tan/code/Show-Images/static/BearHou...       1   CCON
# 226672  /media/hdd/tan/code/Show-Images/static/BearHou...       2   CCON
# 226673  /media/hdd/tan/code/Show-Images/static/BearHou...       3   CCON
# 226674  /media/hdd/tan/code/Show-Images/static/BearHou...       4   CCON
# 226675  /media/hdd/tan/code/Show-Images/static/BearHou...       5   CCON
#
#                                           Path_folder_web camera_angle gender  \
# 226671  BearHouse-Person/CCON_ch7_20230310130001_20230...          ch7  Women
# 226672  BearHouse-Person/CCON_ch7_20230310130001_20230...          ch7  Women
# 226673  BearHouse-Person/CCON_ch7_20230310130001_20230...          ch7  Women
# 226674  BearHouse-Person/CCON_ch7_20230310130001_20230...          ch7  Women
# 226675  BearHouse-Person/CCON_ch7_20230310130001_20230...          ch7  Women
#
#        category work_by status   clip_from split  \
# 226671  Working     Nat    NaN  Bear-House  test
# 226672  Working     Nat    NaN  Bear-House  test
# 226673  Working     Nat    NaN  Bear-House  test
# 226674  Working     Nat    NaN  Bear-House  test
# 226675  Working     Nat    NaN  Bear-House  test
#
#                                               path_img_28
# 226671  /media/HDD/BearHouse-Person/CCON_ch7_202303101...
# 226672  /media/HDD/BearHouse-Person/CCON_ch7_202303101...
# 226673  /media/HDD/BearHouse-Person/CCON_ch7_202303101...
# 226674  /media/HDD/BearHouse-Person/CCON_ch7_202303101...
# 226675  /media/HDD/BearHouse-Person/CCON_ch7_202303101...

# %%
testframe = testframe.append(testframe1)
print(testframe.shape)
# Out:
# (97089, 14)

# %%
img_no_df = testframe[testframe['Path_folder_web'] =='']
paths= list(set(testframe['Path_folder_web']))
for i in range(len(paths)):
    dff = testframe[testframe['Path_folder_web'] ==paths[i]]
    image_no = int(len(dff)/2)
    img_no = dff[dff['img_no'] == image_no]
    img_no_df = img_no_df.append(img_no)
    
print(img_no_df.shape)
img_no_df.head()

path_men = img_no_df['path_img_28'].tolist()
# Out:
# (1299, 14)

# %%
import shutil
import os
path_men_new = []
img_new = []
val_dir = '/media/HDD/BearHouse-Person-Data/data_R3_middleframe/test/'

for i in range(len(path_men)):
    filename = str(i) + '_' + path_men[i].split('/')[-1]
    filename_path = val_dir + filename
    img_new.append(filename)
    path_men_new.append(filename_path)
    # moving image
    dst = os.path.join(val_dir,filename)
    shutil.copyfile(path_men[i], dst)
    
img_no_df['path_img_28_train'] = path_men_new
img_no_df['img_28_train'] = img_new
img_no_df.to_csv('/home/yupaporn/code/EffNet-Person-Classify/data_label_by_tan_09102023_splited_imgpath28_test_middleframe.csv')
