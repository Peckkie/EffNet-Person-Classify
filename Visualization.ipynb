# %%
#Train
import pandas as pd
dataframe = pd.read_csv('/home/yupaporn/code/EffNet-Person-Classify/data_label_by_tan_10082023_splited_imgpath28_train.csv') #แก้ data เปลี่ยนตาม fold
dataframe = dataframe[dataframe['img_no'] ==1]
dataframe.head()
# Out:
# /home/yupaporn/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      Unnamed: 0  Unnamed: 0.1  \
# 0             0             3
# 75           75            21
# 140         140            47
# 265         265            90
# 390         390            92
#
#                                               path_img  img_no    branch  \
# 0    /media/hdd/tan/code/Show-Images/static/BearHou...       1   Fashion
# 75   /media/hdd/tan/code/Show-Images/static/BearHou...       1  Camera16
# 140  /media/hdd/tan/code/Show-Images/static/BearHou...       1  Camera17
# 265  /media/hdd/tan/code/Show-Images/static/BearHou...       1  Camera17
# 390  /media/hdd/tan/code/Show-Images/static/BearHou...       1  Camera16
#
#                                        Path_folder_web camera_angle gender  \
# 0    BearHouse-Person/Fashion_ch3_20230310145957_20...          ch3    Men
# 75   BearHouse-Person/IP Camera16_kku2_kku2_2023061...         kku2    Men
# 140  BearHouse-Person/IP Camera17_kku2_kku2_2023061...         kku2    Men
# 265  BearHouse-Person/IP Camera17_kku2_kku2_2023061...         kku2    Men
# 390  BearHouse-Person/IP Camera16_kku2_kku2_2023061...         kku2    Men
#
#     category work_by status   clip_from  split  \
# 0    Student     Nat    NaN  Bear-House  train
# 75   Student   Frist    NaN  Bear-House  train
# 140  Student    Yoke    NaN  Bear-House  train
# 265  Student     Nat    NaN  Bear-House  train
# 390  Student     Nat    NaN  Bear-House  train
#
#                                            path_img_28
# 0    /media/SSD/BearHouse-Person/Fashion_ch3_202303...
# 75   /media/SSD/BearHouse-Person/IP Camera16_kku2_k...
# 140  /media/SSD/BearHouse-Person/IP Camera17_kku2_k...
# 265  /media/SSD/BearHouse-Person/IP Camera17_kku2_k...
# 390  /media/SSD/BearHouse-Person/IP Camera16_kku2_k...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob
import random
import cv2

# %%
path_men = dataframe[dataframe['gender'] == 'Men']['path_img_28'].tolist()
def plotImages2():
    r = random.sample(path_men, 9)
    plt.figure(figsize=(20,20))
    plt.subplot(331)
    plt.imshow(cv2.imread(r[0])); plt.axis('off')
    plt.subplot(332)
    plt.imshow(cv2.imread(r[1])); plt.axis('off')
    plt.subplot(333)
    plt.imshow(cv2.imread(r[2])); plt.axis('off')
    plt.subplot(334)
    plt.imshow(cv2.imread(r[3])); plt.axis('off')
    plt.subplot(335)
    plt.imshow(cv2.imread(r[4])); plt.axis('off')
    plt.subplot(336)
    plt.imshow(cv2.imread(r[5])); plt.axis('off')
    plt.subplot(337)
    plt.imshow(cv2.imread(r[6])); plt.axis('off')
    plt.subplot(338)
    plt.imshow(cv2.imread(r[7])); plt.axis('off')
    plt.subplot(339)
    plt.imshow(cv2.imread(r[8])); plt.axis('off')
plotImages2()

# %%
path_men = dataframe[dataframe['gender'] == 'Women']['path_img_28'].tolist()
def plotImages2():
    r = random.sample(path_men, 9)
    plt.figure(figsize=(20,20))
    plt.subplot(331)
    plt.imshow(cv2.imread(r[0])); plt.axis('off')
    plt.subplot(332)
    plt.imshow(cv2.imread(r[1])); plt.axis('off')
    plt.subplot(333)
    plt.imshow(cv2.imread(r[2])); plt.axis('off')
    plt.subplot(334)
    plt.imshow(cv2.imread(r[3])); plt.axis('off')
    plt.subplot(335)
    plt.imshow(cv2.imread(r[4])); plt.axis('off')
    plt.subplot(336)
    plt.imshow(cv2.imread(r[5])); plt.axis('off')
    plt.subplot(337)
    plt.imshow(cv2.imread(r[6])); plt.axis('off')
    plt.subplot(338)
    plt.imshow(cv2.imread(r[7])); plt.axis('off')
    plt.subplot(339)
    plt.imshow(cv2.imread(r[8])); plt.axis('off')
plotImages2()

# %%
path_men = dataframe[dataframe['gender'] == 'motorcycle']['path_img_28'].tolist()
def plotImages2():
    r = random.sample(path_men, 9)
    plt.figure(figsize=(20,20))
    plt.subplot(331)
    plt.imshow(cv2.imread(r[0])); plt.axis('off')
    plt.subplot(332)
    plt.imshow(cv2.imread(r[1])); plt.axis('off')
    plt.subplot(333)
    plt.imshow(cv2.imread(r[2])); plt.axis('off')
    plt.subplot(334)
    plt.imshow(cv2.imread(r[3])); plt.axis('off')
    plt.subplot(335)
    plt.imshow(cv2.imread(r[4])); plt.axis('off')
    plt.subplot(336)
    plt.imshow(cv2.imread(r[5])); plt.axis('off')
    plt.subplot(337)
    plt.imshow(cv2.imread(r[6])); plt.axis('off')
    plt.subplot(338)
    plt.imshow(cv2.imread(r[7])); plt.axis('off')
    plt.subplot(339)
    plt.imshow(cv2.imread(r[8])); plt.axis('off')
plotImages2()

# %%
set(dataframe['gender'])
# Out:
# {'Men', 'Women', 'motorcycle'}
